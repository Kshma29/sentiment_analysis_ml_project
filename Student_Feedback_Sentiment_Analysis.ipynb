# %% [markdown]
# <a href="https://colab.research.google.com/github/Kshma29/sentiment_analysis_ml_project/blob/main/Student_Feedback_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from flask import Flask, render_template, url_for
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
trainingData = pd.read_csv("student_feedback_dataset.csv.csv")

# %%
trainingData.sample(frac=1).head(5)
# Out:
#                                                 StudentComments  Rating  \
# 41149  41149                         he is a very good teacher.    4.54
# 22870  22870  he's very good teacher. he can give a very cle...    5.00
# 23399  23399                                            average    3.93
# 10796  10796  his teaching is not understandable most of the...    4.00
# 16419  16419                                           not bad.    5.00
#
#        totalwords Sentiment
# 41149           6  positive
# 22870          20  positive
# 23399           1  positive
# 10796           9  positive
# 16419           2  positive
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *[' '], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_1, *['Rating'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_2, *['totalwords'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_3, *[' '], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_4, *['Rating'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_5, *['totalwords'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_6, *['StudentComments'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_7, *[[[' ', 'Rating'], ['Rating', 'totalwords']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_8, *[' ', 'StudentComments'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_9, *['Rating', 'StudentComments'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_10, *['totalwords', 'StudentComments'], **{'inner': 'stick'})
# chart

# %%
train_X, test_X, train_Y, test_Y = model_selection.train_test_split(trainingData['StudentComments'], trainingData['Sentiment'], test_size = 0.1, random_state = 0)

# %%
df_train = pd.DataFrame()
df_train['StudentComments'] = train_X
df_train['Sentiment'] = train_Y

df_test = pd.DataFrame()
df_test['StudentComments'] = test_X
df_test['Sentiment'] = test_Y

# %%
df_train
# Out:
#                                          StudentComments Sentiment
# 31438  he has some problem in his behaviour.he must t...  negative
# 50066                                he is a bad teacher  negative
# 27225                     his math knowledge is so nice.   neutral
# 49906                                               good  negative
# 19227  he has to increasing teaching capability so th...  positive
# ...                                                  ...       ...
# 21243                               he is a good teacher  positive
# 45891                              he is a good teacher.  negative
# 42613             he is one of the best teacher of aiub.  positive
# 43567                                     he is good one  positive
# 2732                                                good  negative
#
# [46642 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_train, *['Sentiment'], **{})
# chart

# %%
df_test
# Out:
#                                          StudentComments Sentiment
# 2897                                        good teacher  positive
# 33873                                         he is good   neutral
# 11654                           he is quite good teacher  positive
# 30484                                               well  negative
# 43160                                          she's ok!   neutral
# ...                                                  ...       ...
# 18252                                               good  positive
# 14982  very very very experience teacher.,but we r no...  positive
# 48385                              she is a good teacher  positive
# 41291  nice teacher.he is a one of the good teacher o...  positive
# 26976                                       good teacher  positive
#
# [5183 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_test, *['Sentiment'], **{})
# chart

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect = TfidfVectorizer(max_features = 5000)
tfidf_vect.fit(trainingData['StudentComments'].values.astype('U'))
train_x_tfidf = tfidf_vect.transform(df_train['StudentComments'].values.astype('U'))
test_x_tfidf = tfidf_vect.transform(df_test['StudentComments'].values.astype('U'))

# %%
tfidf_vect
# Out:
# TfidfVectorizer(max_features=5000)

# %%
print(train_x_tfidf)
# Out:
#   (0, 4920)	0.21905780559414686
#   (0, 4585)	0.12107308956274916
#   (0, 4550)	0.17369156673287228
#   (0, 4517)	0.11431865227249478
#   (0, 4374)	0.21629318874225575
#   (0, 3988)	0.201838044515464
#   (0, 3399)	0.21381588290426204
#   (0, 2965)	0.24557631763719287
#   (0, 2918)	0.16764888551080387
#   (0, 2845)	0.3605487810727726
#   (0, 2250)	0.12922959873069598
#   (0, 2116)	0.13032694104512774
#   (0, 2110)	0.14959025900892528
weak': 4860, 'co': 828, 'operative': 3119, 'instructer': 2305, 'strict': 4195, 'making': 2706, 'quite': 3514, 'person': 3250, 'correct': 1021, 'ideas': 2193, 'method': 2840, 'was': 4846, 'when': 4888, 'then': 4524, 'seems': 3793, 'be': 524, 'knowledgful': 2498, 'which': 4893, 'exception': 1489, 'kind': 2469, 'motivating': 2933, 'makes': 2704, 'easier': 1320, 'appreciatable': 294, 'personality': 3255, 'style': 4227, 'outstandig': 3162, 'smiling': 3958, 'face': 1584, 'didnt': 1193, 'go': 1863, 'another': 258, 'chapter': 775, 'ver': 4790, 'any': 268, 'it': 2378, 'grade': 1917, 'honesty': 2141, 'sincere': 3914, 'responsible': 3671, 'respect': 3657, 'teaches': 4432, 'tried': 4631, 'how': 2158, 'that': 4513, 'why': 4904, 'clear': 816, 'complaints': 898, 'teature': 4456, 'conducting': 933, 'enjoy': 1405, 'know': 2486, 'pass': 3212, 'generous': 1829, 'freidly': 1757, 'reguler': 3604, 'expressive': 1568, 'admire': 113, 'heis': 2068, 'helpfull': 2077, 'cares': 740, 'manner': 2731, 'influence': 2276, 'many': 2740, 'things': 4544, 'should': 3878, 'preference': 3359, 'quize': 3517, 'or': 3129, 'assignment': 373, 'coz': 1045, 'there': 4532, 'every': 1449, 'meaning': 2799, 'delivers': 1132, 'speech': 4088, 'enjoyed': 1407, 'lot': 2657, 'allrounder': 195, 'activities': 96, 'strong': 4201, 'each': 1310, 'quality': 3500, 'at': 387, 'bonus': 644, 'marks': 2750, 'lecturer': 2578, 'explains': 1555, 'operating': 3117, 'just': 2442, 'alright': 206, 'provide': 3473, 'examples': 1473, 'summary': 4302, 'hand': 2008, 'writing': 4961, 'small': 3948, 'see': 3788, 'sometimes': 4006, 'becomes': 537, 'angry': 254, 'f ...

# %%
from sklearn.svm import SVC

model = SVC(kernel='poly', degree = 3, C=1)
model.fit(train_x_tfidf, train_Y)
# Out:
# SVC(C=1, kernel='poly')

# %%
from sklearn.metrics import accuracy_score

predictions_svm = model.predict(test_x_tfidf)
test_prediction = pd.DataFrame()
test_prediction['StudentComments'] = test_X
test_prediction['Sentiment'] = predictions_svm.astype(str)
svm_accuracy = accuracy_score(predictions_svm, test_Y.astype(str))*100
svm_accuracy = round(svm_accuracy, 1)

# %%
test_prediction
# Out:
#                                          StudentComments Sentiment
# 2897                                        good teacher  positive
# 33873                                         he is good  positive
# 11654                           he is quite good teacher  positive
# 30484                                               well  positive
# 43160                                          she's ok!  positive
# ...                                                  ...       ...
# 18252                                               good  positive
# 14982  very very very experience teacher.,but we r no...  positive
# 48385                              she is a good teacher  positive
# 41291  nice teacher.he is a one of the good teacher o...  positive
# 26976                                       good teacher  positive
#
# [5183 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(test_prediction, *['Sentiment'], **{})
# chart

# %%
svm_accuracy
# Out:
# 82.8

# %%
from sklearn.metrics import classification_report

print(classification_report(test_Y.astype(str), predictions_svm.astype(str)))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.78      0.20      0.32       558
#      neutral       0.68      0.06      0.11       441
#     positive       0.83      0.99      0.90      4184
#
#     accuracy                           0.83      5183
#    macro avg       0.76      0.42      0.45      5183
# weighted avg       0.81      0.83      0.77      5183
